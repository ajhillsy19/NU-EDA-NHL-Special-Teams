# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
df = pd.read_csv('all_specialteams.csv')

# %%
#Let's start combining the special teams.

fig = px.scatter(df, x="STS/60", y="ST TOI%",hover_name="Player", hover_data=['Pos', 'PP TOI%', 'SH TOI%'], 
                 title="ST TOI% vs STS/60", width=800, height=800,size_max=10,size='GP',opacity=.75)

x_mean = round(df["STS/60"].mean(), 0)
y_mean = round(df["ST TOI%"].mean(), 0)

x_unicorn = np.percentile(df["STS/60"], 95)
y_unicorn = np.percentile(df["ST TOI%"], 95)

print('midpoint',x_mean,y_mean)
fig.add_hline(y=y_mean).add_vline(x=x_mean).add_hline(
    y=y_unicorn, line_dash = 'dash', line_color = 'red').add_vline(
    x=x_unicorn, line_dash = 'dash', line_color = 'red')

fig.write_html("ST TOI% vs STS per 60.html")
# Out:
# midpoint -1.0 57.0
# <div>                            <div id="80e406b0-7485-49e6-b940-bcf08443dbb4" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80e406b0-7485-49e6-b940-bcf08443dbb4")) {                    Plotly.newPlot(                        "80e406b0-7485-49e6-b940-bcf08443dbb4",                        [{"customdata": [["R", 56.2, 17.9], ["C", 55.2, 12.2], ["D", 9.3, 9.0], ["L", 45.2, 32.0], ["D", 11.2, 12.0], ["C", 59.2, 36.6], ["C", 71.9, 7.2], ["C", 68.0, 14.7], ["C", 7.4, 43.8], ["C", 10.7, 47.8], ["C", 69.5, 14.3], ["R", 39.1, 6.8], ["D", 44.7, 42.3], ["R", 59.7, 18.4], ["C", 64.6, 9.5], ["D", 2.1, 60.7], ["C", 66.1, 9.8], ["C", 64.7, 18.8], ["R", 39.4, 33.1], ["D", 7.5, 19.4], ["D", 62.5, 8.9], ["D", 69.0, 46.4], ["D", 66.3, 6.1], ["D", 48.9, 41.1], ["D", 14.7, 52.7], ["L", 39.6, 24.8], ["C", 63.0, 18.0], ["L", 60.0, 20.7], ["C", 59.4, 38.0], ["C", 52.7, 3.7], ["D", 56.0, 14.1], ["C", 63.4, 9.5], ["D", 53.8, 41.7], ["R", 16.1, 25.1], ["L", 59.4, 10.7], ["R", 59.2, 6.8], ["C", 25.8, 25.9], ["C", 56.3, 31.1], ["C", 63.6, 13.3], ["D", 64.1, 48.4], ["C", 8.2, 30.7], ["C", 56.5, 4.2], ["R", 43.3, 20.4], ["C", 54.9, 2.4], ["D", 50.1, 46.1], ["L", 10.7, 34.1], ["C", 31.8, 42.0], ["C", 50.1, 13.1], ["D", 17.0, 24.3], ["C", 40.4, 7.4], ["C", 2.1, 44.6], ["L", 50.8, 34.9], ["C", 60.1, 29.1], ["C", 67.8, 9.8], ["D", 65.0, 36.8], ["C", 19.9, 32.8], ["L", 17.4, 26.0], ["R", 60.1, 22.1], ["C", 54.1, 16.2], ["R", 34.8, 16.7], ["D", 12.9, 43.8], ["C", 56.9, 8.5], ["R", 48.2, 7.8], ["C", 58.1, 8.2], ["C", 50.5, 20.9], ["L", 40.9, 33.5], ["D", 41.1, 27.3], ["C", 9.1, 22.7], ["L", 35.8, 7.0], ["C", 19.2, 26.7], ["D", 33.0, 44.0], ["L", 55.1, 7.0], ["C", 42.2, 44.2], ["C", 42.9